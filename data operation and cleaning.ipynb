# %%
import numpy as np
import pandas as pd

# %%
#creating a dataframe from dictionary

# %%
df=pd.DataFrame({'age':[12,13,14,15,17,18],'height':[120,123,145,136,198,145],'weight':[56,78,87,90,56,80]})
df
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78
# 2   14     145      87
# 3   15     136      90
# 4   17     198      56
# 5   18     145      80

# %%
df.head(2)
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78

# %%
#by default it read top 5
df.head()
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78
# 2   14     145      87
# 3   15     136      90
# 4   17     198      56

# %%
# it gives value from last row ...
df.tail(3)
# Out:
#    age  height  weight
# 3   15     136      90
# 4   17     198      56
# 5   18     145      80

# %%
# it retuns tuple of rows and columns
df.shape
# Out:
# (6, 3)

# %%
type(df.shape)
# Out:
# tuple

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     6 non-null      int64
#  1   height  6 non-null      int64
#  2   weight  6 non-null      int64
# dtypes: int64(3)
# memory usage: 272.0 bytes

# %%
df.describe()
# Out:
#              age      height     weight
# count   6.000000    6.000000   6.000000
# mean   14.833333  144.500000  74.500000
# std     2.316607   28.275431  14.989997
# min    12.000000  120.000000  56.000000
# 25%    13.250000  126.250000  61.500000
# 50%    14.500000  140.500000  79.000000
# 75%    16.500000  145.000000  85.250000
# max    18.000000  198.000000  90.000000

# %%
df.describe().T
# Out:
#         count        mean        std    min     25%    50%     75%    max
# age       6.0   14.833333   2.316607   12.0   13.25   14.5   16.50   18.0
# height    6.0  144.500000  28.275431  120.0  126.25  140.5  145.00  198.0
# weight    6.0   74.500000  14.989997   56.0   61.50   79.0   85.25   90.0

# %%
import seaborn as sns

# %%
df1=sns.load_dataset('titanic')
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df1.isnull().sum()/891*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df1.isnull().sum()/df1.shape[0]*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df1['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df1['age'].mean()
# Out:
# 29.69911764705882

# %%
df1['age'].median()
# Out:
# 28.0

# %%
df1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df1["age"].fillna(df1["age"].median(),inplace=True)

# %%
df1["age"].isna().sum()
# Out:
# 0

# %%
df1["age"].mean()
# Out:
# 29.36158249158249

# %%
df1["embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df1["embarked"].mode()
# Out:
# 0    S
# dtype: object

# %%
df1["embarked"].fillna(df1["embarked"].mode()[0],inplace=True)

# %%
df1.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1["embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
df1["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
df1["alive"].nunique()
# Out:
# 2

# %%
df1["survived"].count()
# Out:
# 891

# %%
(df1["survived"].value_counts()/df1["survived"].count())*100
# Out:
# 0    61.616162
# 1    38.383838
# Name: survived, dtype: float64

# %%
# hoe to drop column
df1.drop(columns=["deck","embark_town"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35964/1746528906.py in <module>
#       1 # hoe to drop column
# ----> 2 df1.drop(columns=["deck","embark_town"],inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male alive  alone
# ...

# %%
df1[["age","sex","fare","alive"]]
# Out:
#       age     sex     fare alive
# 0    22.0    male   7.2500    no
# 1    38.0  female  71.2833   yes
# 2    26.0  female   7.9250   yes
# 3    35.0  female  53.1000   yes
# 4    35.0    male   8.0500    no
# ..    ...     ...      ...   ...
# 886  27.0    male  13.0000    no
# 887  19.0  female  30.0000   yes
# 888  28.0  female  23.4500    no
# 889  26.0    male  30.0000   yes
# 890  32.0    male   7.7500    no
#
# [891 rows x 4 columns]

# %%
df1.loc[60:70,["survived","fare"]]
# Out:
#     survived     fare
# 60         0   7.2292
# 61         1  80.0000
# 62         0  83.4750
# 63         0  27.9000
# 64         0  27.7208
# 65         1  15.2458
# 66         1  10.5000
# 67         0   8.1583
# 68         1   7.9250
# 69         0   8.6625
# 70         0  10.5000

# %%
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df1["fare"]);

# %%
q3+1.5*iqr

# %%
iqr=stats.iqr(df1["fare"])
iqr
# Out:
# 23.0896

# %%
df1["fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
a=31+1.5*iqr
a
# Out:
# 65.6344

# %%
len(df1[df1["fare"]>a])
# Out:
# 116

# %%
import numpy as np

# %%
np.quantile(df1["age"],[0.10,0.25,0.50,0.75,0.90,0.99,0.999,1.0])
# Out:
# array([16.  , 22.  , 28.  , 35.  , 47.  , 65.  , 74.66, 80.  ])

# %%
np.percentile(df1["age"],[0,10,25,50,75,90,99,100])
# Out:
# array([ 0.42, 16.  , 22.  , 28.  , 35.  , 47.  , 65.  , 80.  ])

# %%
# indexing and slicing and dataframe
iloc,loc
iloc- indexes are numbers
loc-named indexes

# %%
df1.iloc[50:101,2:7]
# Out:
#         sex    age  sibsp  parch      fare
# 50     male   7.00      4      1   39.6875
# 51     male  21.00      0      0    7.8000
# 52   female  49.00      1      0   76.7292
# 53   female  29.00      1      0   26.0000
# 54     male  65.00      0      1   61.9792
# 55     male  28.00      0      0   35.5000
# 56   female  21.00      0      0   10.5000
# 57     male  28.50      0      0    7.2292
# 58   female   5.00      1      2   27.7500
# 59     male  11.00      5      2   46.9000
# 60     male  22.00      0      0    7.2292
# 61   female  38.00      0      0   80.0000
# 62     male  45.00      1      0   83.4750
# 63     male   4.00      3      2   27.9000
# 64     male  28.00      0      0   27.7208
# 65     male  28.00      1      1   15.2458
# 66   female  29.00      0      0   10.5000
# 67     male  19.00      0      0    8.1583
# 68   female  17.00      4      2    7.9250
# 69     male  26.00      2      0    8.6625
# 70     male  32.00      0      0   10.5000
# ...

# %%
df2=pd.DataFrame({"marks":[33,4,65,77]},index=["golu","molu","bholu","neha"])
df2.loc[["golu","neha"]]
# Out:
#       marks
# golu     33
# neha     77

# %%
df2.loc["golu":"neha"]
# Out:
#        marks
# golu      33
# molu       4
# bholu     65
# neha      77

# %%
import numpy as np
import pandas as pd

# %%
a=np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
col=pd.Series(a)
type(col)
# Out:
# pandas.core.series.Series

# %%
df=pd.DataFrame(col,columns=["col1"])

# %%
df
# Out:
#    col1
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
df["col2"]=[10,11,13,12,14]

# %%
df
# Out:
#    col1  col2
# 0     1    10
# 1     2    11
# 2     3    13
# 3     4    12
# 4     5    14

# %%
pd.series([10,11,12,13,14]),index=

# %%
df1[(df1["sex"]=="male") & (df1["alive"]=="yes")]["class"]
# Out:
# 17     Second
# 21     Second
# 23      First
# 36      Third
# 55      First
#         ...
# 838     Third
# 839     First
# 857     First
# 869     Third
# 889     First
# Name: class, Length: 109, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df1[(df1["sex"]=="male") & (df1["alive"]=="yes")]["class"].value_counts()
# Out:
# Third     47
# First     45
# Second    17
# Name: class, dtype: int64

# %%
df1[(df1["sex"]=="male") & (df1["alive"]=="yes")][["class","fare","age"]].value_counts()
# Out:
# class   fare     age
# Third   56.4958  32.0    2
#                  28.0    2
# First   26.5500  28.0    2
#         35.5000  28.0    2
# Third   15.2458  28.0    2
#                         ..
# First   89.1042  49.0    1
#         81.8583  4.0     1
#         79.2000  60.0    1
#         76.7292  48.0    1
# Second  18.7500  3.0     1
# Length: 104, dtype: int64

# %%
df1[(df1["sex"]=="female") & (df1["alive"]=="yes")]["fare"].mean()
# Out:
# 51.93857339055791

# %%
df1[(df1["age"]<18)]["survived"].value_counts()
# Out:
# 1    61
# 0    52
# Name: survived, dtype: int64

# %%
df3=sns.load_dataset("diamonds")
df3
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Aggregation...

# %%
df3.groupby("cut")["price"].mean()
# Out:
# cut
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Good         3928.864452
# Fair         4358.757764
# Name: price, dtype: float64

# %%
df3.groupby(["cut","clarity"])["price"].mean()
# Out:
# cut        clarity
# Ideal      IF         2272.913366
#            VVS1       2468.129458
#            VVS2       3250.290100
#            VS1        3489.744497
#            VS2        3284.550385
#            SI1        3752.118169
#            SI2        4755.952656
#            I1         4335.726027
# Premium    IF         3856.143478
#            VVS1       2831.206169
#            VVS2       3795.122989
#            VS1        4485.462041
#            VS2        4550.331248
#            SI1        4455.269371
#            SI2        5545.936928
#            I1         3947.331707
# Very Good  IF         4396.216418
#            VVS1       2459.441065
#            VVS2       3037.765182
#            VS1        3805.353239
#            VS2        4215.759552
#            SI1        3932.391049
#            SI2        4988.688095
#            I1         4078.226190
# Good       IF         4098.323944
#            VVS1       2254.774194
#            VVS2       3079.108392
# ...

# %%
df3["color"].unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df3.groupby("cut")["color"].value_counts()
# Out:
# cut
# Ideal      G    4884
#            E    3903
#            F    3826
#            H    3115
#            D    2834
#            I    2093
#            J     896
# Premium    G    2924
#            H    2360
#            E    2337
#            F    2331
#            D    1603
#            I    1428
#            J     808
# Very Good  E    2400
#            G    2299
#            F    2164
#            H    1824
#            D    1513
#            I    1204
#            J     678
# Good       E     933
#            F     909
#            G     871
#            H     702
#            D     662
#            I     522
#            J     307
# Fair       G     314
#            F     312
#            H     303
#            E     224
#            I     175
#            D     163
#            J     119
# Name: color, dtype: int64

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.groupby(["pclass","sex"])["survived"].value_counts()
# Out:
# pclass  sex     survived
# 1       female  1            91
#                 0             3
#         male    0            77
#                 1            45
# 2       female  1            70
#                 0             6
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: survived, dtype: int64

# %%
df1.groupby(["pclass","survived"])["sex"].value_counts()
# Out:
# pclass  survived  sex
# 1       0         male       77
#                   female      3
#         1         female     91
#                   male       45
# 2       0         male       91
#                   female      6
#         1         female     70
#                   male       17
# 3       0         male      300
#                   female     72
#         1         female     72
#                   male       47
# Name: sex, dtype: int64

# %%
a=df1.groupby(["pclass","sex"])["survived"].count()

# %%
(df1.groupby(["pclass","sex"])["survived"].value_counts()/a*100)
# Out:
# pclass  sex     survived
# 1       female  1           96.808511
#                 0            3.191489
#         male    0           63.114754
#                 1           36.885246
# 2       female  1           92.105263
#                 0            7.894737
#         male    0           84.259259
#                 1           15.740741
# 3       female  0           50.000000
#                 1           50.000000
#         male    0           86.455331
#                 1           13.544669
# Name: survived, dtype: float64

# %%
df1.groupby(["pclass","sex"])["fare"].min()
# Out:
# pclass  sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: fare, dtype: float64

# %%
df1.groupby(["pclass","sex"])["fare"].max()
# Out:
# pclass  sex
# 1       female    512.3292
#         male      512.3292
# 2       female     65.0000
#         male       73.5000
# 3       female     69.5500
#         male       69.5500
# Name: fare, dtype: float64

# %%
df1.groupby(["pclass","sex"])["fare"].mean()
# Out:
# pclass  sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: fare, dtype: float64

# %%
#agregate
df1.groupby(["pclass","sex"])["fare"].agg(["min","max","mean","median","std","var"])
# Out:
#                    min       max        mean    median        std          var
# pclass sex
# 1      female  25.9292  512.3292  106.125798  82.66455  74.259988  5514.545830
#        male     0.0000  512.3292   67.226127  41.26250  77.548021  6013.695545
# 2      female  10.5000   65.0000   21.970121  22.00000  10.891796   118.631214
#        male     0.0000   73.5000   19.741782  13.00000  14.922235   222.673090
# 3      female   6.7500   69.5500   16.118810  12.47500  11.690314   136.663446
#        male     0.0000   69.5500   12.661633   7.92500  11.681696   136.462010

# %%
df1.groupby(["pclass","sex"])["survived"].agg(["min","max","mean","median","std","var"])
# Out:
#                min  max      mean  median       std       var
# pclass sex
# 1      female    0    1  0.968085     1.0  0.176716  0.031229
#        male      0    1  0.368852     0.0  0.484484  0.234724
# 2      female    0    1  0.921053     1.0  0.271448  0.073684
#        male      0    1  0.157407     0.0  0.365882  0.133870
# 3      female    0    1  0.500000     0.5  0.501745  0.251748
#        male      0    1  0.135447     0.0  0.342694  0.117439

# %%
#np.where
import numpy as np

# %%
df1.iloc[np.where(df1["fare"]>100)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 31          1       1  female    NaN      1      0  146.5208        C  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 195         1       1  female  58.00      0      0  146.5208        C  First
# 215         1       1  female  31.00      1      0  113.2750        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# ...

# %%
df1.iloc[np.where(df1["fare"]>100)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 31          1       1  female    NaN      1      0  146.5208        C  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 195         1       1  female  58.00      0      0  146.5208        C  First
# 215         1       1  female  31.00      1      0  113.2750        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# ...

# %%
df4=sns.load_dataset("tips")

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df4["new"]=df4["total_bill"]+df4["tip"]

# %%
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size    new
# 0         16.99  1.01  Female     No   Sun  Dinner     2  18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  28.20
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  21.78
#
# [244 rows x 8 columns]

# %%
df4["new"]=df4["new"].apply(lambda x: np.log(x))
df4
# Out:
#      total_bill   tip     sex smoker   day    time  size       new
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.061385
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.910235
# 2         21.01  3.50    Male     No   Sun  Dinner     3  1.162864
# 3         23.68  3.31    Male     No   Sun  Dinner     2  1.192548
# 4         24.59  3.61  Female     No   Sun  Dinner     4  1.205768
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1.268051
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.215946
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.164896
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.089907
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.125252
#
# [244 rows x 8 columns]

# %%
a=lambda pi,r:4/3*pi*r**3
a(3.14,10)
# Out:
# 4186.666666666667

# %%
# define  a function using lambda which comvert farenhite to celcius and vice versa
farenhite_to_celcius=lambda f: (f-32)*5/9 
farenhite_to_celcius(100)
# Out:
# 37.77777777777778

# %%
celcius_to_farenhite=lambda c :(c*9/5)+32
celcius_to_farenhite(37.77777777777778)
# Out:
# 100.0
